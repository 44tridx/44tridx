# %% [markdown]
# <a href="https://colab.research.google.com/github/44tridx/44tridx/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import randint
computador = randint(0, 10)
print('Sou seu computador... Acabei de pensar em um número entire e 10.')
print('Será que você consegue adivinhar qual foi?')
acertou = False
palpites = 0
while not acertou:
    jogador = int(input('Qual é seu palpite? '))
    palpites += 1
    if jogador == computador:
        acertou = True
    else:
        if jogador < computador:
          print('Mais... Tents mais uma vez.')
        elif jogador > computador:
            print('Menos... Tente mais uma vez.')
print('Acertou com {} tentativas. Parabéns!'.format(palpites))
# Out:
# Sou seu computador... Acabei de pensar em um número entire e 10.
# Será que você consegue adivinhar qual foi?
# Qual é seu palpite? 5
# Mais... Tents mais uma vez.
# Qual é seu palpite? 8
# Menos... Tente mais uma vez.
# Qual é seu palpite? 3
# Mais... Tents mais uma vez.
# Qual é seu palpite? 6
# Acertou com 4 tentativas. Parabéns!
